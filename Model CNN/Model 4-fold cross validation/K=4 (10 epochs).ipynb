# %% [markdown]
# # Setup and Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1.1 Install Dependencies

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dense, Flatten
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.backend import clear_session
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %%
cd /content/drive/MyDrive/TugasAkhir/dataset2
# Out:
# /content/drive/.shortcut-targets-by-id/1v5oPJ5JOYzUAa4YaNYNkGN60oi8ikFKw/dataset2

# %%
directories = os.listdir()

filename = []
label = []
for i in range(0, len(directories)):
  os.chdir(directories[i])
  print(os.getcwd())
  files = os.listdir()
  for j in range(0, len(files)):
    files[j] = directories[i] + "/" + files[j]
    label.append(directories[i])
    print(files[j])
  filename = filename + files
  os.chdir("..")
print(filename)
print(label)
# Out:
# /content/drive/.shortcut-targets-by-id/1v5oPJ5JOYzUAa4YaNYNkGN60oi8ikFKw/dataset2/fresh
# fresh/20221024_071252.jpg
# fresh/20221024_071335.jpg
# fresh/20221024_071411.jpg
# fresh/20221024_071445.jpg
# fresh/20221024_071514.jpg
# fresh/20221024_071546.jpg
# fresh/20221024_071610.jpg
# fresh/20221024_091728.jpg
# fresh/20221024_091800.jpg
# fresh/20221024_092018.jpg
# fresh/20221024_092036.jpg
# fresh/20221024_092106.jpg
# fresh/20221028_193042.jpg
# fresh/20221028_193103.jpg
# fresh/20221028_193124.jpg
# fresh/20221028_193147.jpg
# fresh/20221028_193211(0).jpg
# fresh/20221028_193242.jpg
# fresh/20221028_193308.jpg
# fresh/20221028_193333.jpg
# fresh/20221028_193353.jpg
# fresh/20221028_193416.jpg
# fresh/20221028_193431.jpg
# fresh/20221028_193447.jpg
# fresh/20221028_193510.jpg
# fresh/20221028_193524.jpg
# fresh/20221028_193538.jpg
# fresh/20221028_193551.jpg
# fresh/20221028_193618.jpg
# fresh/20221028_193640.jpg
# fresh/20221028_193703(0).jpg
# fresh/20221028_193719.jpg
# fresh/20221028_193753.jpg
# fresh/20221028_193806.jpg
# fresh/20221028_193828.jpg
# fresh/20221028_193843.jpg
# fresh/20221028_194735.jpg
# fresh/20221028_194835.jpg
# fresh/20221028_194907.jpg
# fresh/20221028_194944(0).jpg
# fresh/20221028_195032(0).jpg
# fresh/20221028_195058.jpg
# fresh/20221028_200744.jpg
# fresh/20221028_200809.jpg
# fresh/20221028_200825(0).jpg
# fresh/20221028_200841.jpg
# fresh/20221028_200915(0).jpg
# fresh/20221028_200930.jpg
# fresh/20221028_200952.jpg
# fresh/20221028_201006.jpg
# fresh/20221028_201020.jpg
# fresh/20221028_201040.jpg
# fresh/20221028_201109.jpg
# fresh/20221028_201124.jpg
# fresh/20221028_201140.jpg
# fresh/20221028_201201.jpg
# fresh/20221028_201216.jpg
# fresh/20221028_201231.jpg
# fresh/20221028_215405.jpg
# fresh/20221028_215427.jpg
# fresh/20221028_215444.jpg
# fresh/20221028_215511.jpg
# fresh/20221028_215535.jpg
# fresh/20221028_215616.jpg
# fresh/20221028_215634.jpg
# fresh/20221028_215649.jpg
# fresh/20221028_215714.jpg
# fresh/20221028_215737.jpg
# fresh/20221028_215806.jpg
# fresh/20221028_215829.jpg
# fresh/20221028_215849.jpg
fresh/20221028_220220.jpg', 'fresh/20221028_220237(0).jpg', 'fresh/20221028_220545(0).jpg', 'fresh/20221028_220609.jpg', 'fresh/20221028_220700(0).jpg', 'fresh/20221028_220718(0).jpg', 'fresh/20221028_220738.jpg', 'fresh/20221028_220858.jpg', 'fresh/20221028_220920.jpg', 'fresh/20221028_221031.jpg', 'fresh/20221028_221048.jpg', 'fresh/20221028_221107(0).jpg', 'fresh/20221028_221126.jpg', 'fresh/20221028_221140.jpg', 'fresh/20221028_221154.jpg', 'fresh/20221028_221209.jpg', 'fresh/20221028_221225(0).jpg', 'fresh/20221028_221240.jpg', 'fresh/20221028_221257.jpg', 'fresh/20221028_221311.jpg', 'fresh/20221028_221326(0).jpg', 'fresh/20221028_221344.jpg', 'fresh/20221028_221401.jpg', 'fresh/20221028_221420.jpg', 'fresh/20221028_221431.jpg', 'fresh/20221028_221443.jpg', 'fresh/20221028_221456.jpg', 'fresh/20221028_221512.jpg', 'fresh/20221028_221524.jpg', 'fresh/20221031_071829.jpg', 'fresh/20221031_071850.jpg', 'fresh/20221031_071911.jpg', 'fresh/20221031_071925.jpg', 'fresh/20221031_071945.jpg', 'fresh/20221031_072000.jpg', 'fresh/20221031_072021.jpg', 'fresh/20221031_072033(0).jpg', 'fresh/20221031_072048.jpg', 'fresh/20221031_072102.jpg', 'fresh/20221031_072117(0).jpg', 'fresh/20221031_072131.jpg', 'fresh/20221031_072142.jpg', 'fresh/20221031_072154.jpg', 'fresh/20221031_072205.jpg', 'fresh/20221031_072216(0).jpg', 'fresh/20221031_072242.jpg', 'fresh/20221031_072301(0).jpg', 'fresh/20221031_072316.jpg', 'fresh/20221031_072330.jpg', 'fresh/20221031_072342(0).jpg', 'fresh/20221031_072352.jpg', 'fresh/20221031_072417(0).jpg', 'fresh/20221031_072427.jpg', 'fresh/20221031_072443.jpg', 'fresh/20221031_072458.jpg', 'fresh/20221031_072508(0).jpg', 'fresh/20221031_072523.jpg', 'fresh/20221031 ...
# ['fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'fresh', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasible', 'notfeasi ...

# %%
print(len(filename))
# Out:
# 540

# %% [markdown]
# Save List of Images to Pandas

# %%
import pandas as pd

data = {"filename": filename,
        "label": label
        }

df = pd.DataFrame(data = data)

# %% [markdown]
# Print List of Images files

# %%
print(df)
# Out:
#                                filename        label
# 0             fresh/20221024_071252.jpg        fresh
# 1             fresh/20221024_071335.jpg        fresh
# 2             fresh/20221024_071411.jpg        fresh
# 3             fresh/20221024_071445.jpg        fresh
# 4             fresh/20221024_071514.jpg        fresh
# ..                                  ...          ...
# 535     notfeasible/20221031_175526.jpg  notfeasible
# 536  notfeasible/20221031_175536(0).jpg  notfeasible
# 537     notfeasible/20221031_175548.jpg  notfeasible
# 538     notfeasible/20221031_175600.jpg  notfeasible
# 539     notfeasible/20221031_175611.jpg  notfeasible
#
# [540 rows x 2 columns]

# %% [markdown]
# Randomize the List of Image Files

# %%
df_shuffled = df.sample(frac = 1)
print(df_shuffled)
# Out:
#                             filename        label
# 256         good/20221029_024357.jpg         good
# 330      good/20221031_131448(0).jpg         good
# 185         good/20221024_131654.jpg         good
# 87         fresh/20221028_221031.jpg        fresh
# 523  notfeasible/20221031_175223.jpg  notfeasible
# ..                               ...          ...
# 137        fresh/20221031_072600.jpg        fresh
# 402  notfeasible/20221029_065235.jpg  notfeasible
# 315         good/20221031_113131.jpg         good
# 461  notfeasible/20221029_094004.jpg  notfeasible
# 387  notfeasible/20221029_064651.jpg  notfeasible
#
# [540 rows x 2 columns]

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import KFold

train_data = df_shuffled

Y = train_data[['label']]

# number of split is 4
kf = KFold(n_splits = 4)

# %% [markdown]
# Preprocessing the Training Set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# Preprocessing the Test Set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# ## Building the CNN Model

# %% [markdown]
# Define the directories of dataset

# %%
image_dir = '/content/drive/MyDrive/TugasAkhir/dataset2'

# %% [markdown]
# Method for save the best CNN model

# %%
def get_model_name(k):
  return 'model_' + str(k) + '.h5'

# %% [markdown]
# Import and define the performance metric

# %%
import time
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

VALIDATION_ACCURACY = []
VALIDATION_PRECISION = []
VALIDATION_RECALL = []
VALIDATION_F1SCORE = []

CV = []

LOSS = []
ACCURACY = []

VAL_LOSS = []
VAL_ACCURACY = []

# %% [markdown]
# # Build and Train the CNN Model

# %%
save_dir = '/saved_models/'
fold_var = 1

# Looping for each cross validation
for train_index, val_index in kf.split(np.zeros(len(Y)), Y):
  training_data = train_data.iloc[train_index]
  validation_data = train_data.iloc[val_index]

  train_data_generator = train_datagen.flow_from_dataframe(training_data, directory = image_dir,
                                                           x_col = "filename", y_col = "label",
                                                           target_size = (256, 256), batch_size = 32,
                                                           class_mode = "categorical", shuffle = False)
  
  valid_data_generator = test_datagen.flow_from_dataframe(validation_data, directory = image_dir,
                                                           x_col = "filename", y_col = "label",
                                                           target_size = (256, 256), batch_size = 32,
                                                           class_mode = "categorical", shuffle = False)
  
  model = Sequential()
  model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
  model.add(MaxPooling2D())

  model.add(Conv2D(32, (3,3), 1, activation='relu'))
  model.add(MaxPooling2D())

  model.add(Conv2D(16, (3,3), 1, activation='relu'))
  model.add(MaxPooling2D())

  model.add(Flatten())

  model.add(Dense(256, activation='relu'))
  model.add(Dense(3, activation='softmax'))

  model.summary

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  checkpoint = ModelCheckpoint(save_dir+get_model_name(fold_var),
                               monitor = 'val_accuracy', verbose = 1,
                               save_best_only = True, mode = 'max')
  
  callback_list = [checkpoint]

  hist = model.fit(train_data_generator, 
                   epochs = 10, 
                   callbacks = callback_list, 
                   validation_data = valid_data_generator)
  
  model.load_weights("/saved_models/model_" + str(fold_var) + ".h5")

  results = model.evaluate(valid_data_generator)
  results = dict(zip(model.metrics_names, results))

  y_predict = model.predict(valid_data_generator)

  # get the label of validation data
  y = np.asarray(valid_data_generator.labels)

  # Karena output multilable adalah 0 - 1 dari tiap class maka diambil yg terbesar
  y_predict_labels = np.argmax(y_predict, axis=1)

  acc = accuracy_score(y_predict_labels, y)
  prec = precision_score(y_predict_labels, y, average = 'weighted')
  rec = recall_score(y_predict_labels, y, average = 'weighted')
  f1score = f1_score(y_predict_labels, y, average = 'weighted')

  print("\n")
  print("Cross Validation: ", fold_var)
  print("accuracy: ", results['accuracy'])
  print("precision: ", prec)
  print("recall: ", rec)
  print("f1 score: ", f1score)
  print("\n")

  VALIDATION_ACCURACY.append(results['accuracy'])
  VALIDATION_PRECISION.append(prec)
  VALIDATION_RECALL.append(rec)
  VALIDATION_F1SCORE.append(f1score)

  LOSS.append(hist.history['loss'])
  ACCURACY.append(hist.history['accuracy'])

  VAL_LOSS.append(hist.history['val_loss'])
  VAL_ACCURACY.append(hist.history['val_accuracy'])

  CV.append("CV" + str(fold_var))

  clear_session()

  fold_var += 1
# Out:
# Found 405 validated image filenames belonging to 3 classes.
# Found 135 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.2351 - accuracy: 0.3877
# Epoch 1: val_accuracy improved from -inf to 0.28148, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 355s 28s/step - loss: 1.2351 - accuracy: 0.3877 - val_loss: 1.0969 - val_accuracy: 0.2815
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0542 - accuracy: 0.4346
# Epoch 2: val_accuracy improved from 0.28148 to 0.48148, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 32s 2s/step - loss: 1.0542 - accuracy: 0.4346 - val_loss: 0.9969 - val_accuracy: 0.4815
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8844 - accuracy: 0.5901
# Epoch 3: val_accuracy improved from 0.48148 to 0.57037, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 29s 2s/step - loss: 0.8844 - accuracy: 0.5901 - val_loss: 0.8777 - val_accuracy: 0.5704
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6764 - accuracy: 0.7062
# Epoch 4: val_accuracy improved from 0.57037 to 0.74074, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.6764 - accuracy: 0.7062 - val_loss: 0.6136 - val_accuracy: 0.7407
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4978 - accuracy: 0.7926
# Epoch 5: val_accuracy did not improve from 0.74074
# 13/13 [==============================] - 32s 3s/step - loss: 0.4978 - accuracy: 0.7926 - val_loss: 0.7540 - val_accuracy: 0.6074
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4169 - accuracy: 0.8321
# Epoch 6: val_accuracy improved from 0.74074 to 0.81481, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 32s 2s/step - loss: 0.4169 - accuracy: 0.8321 - val_loss: 0.4151 - val_accuracy: 0.8148
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9111
# Epoch 7: val_accuracy improved from 0.81481 to 0.88148, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.2676 - accuracy: 0.9111 - val_loss: 0.3015 - val_accuracy: 0.8815
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.9309
# Epoch 8: val_accuracy improved from 0.88148 to 0.88889, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.1927 - accuracy: 0.9309 - val_loss: 0.2656 - val_accuracy: 0.8889
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9259
# Epoch 9: val_accuracy did not improve from 0.88889
# 13/13 [==============================] - 28s 2s/step - loss: 0.1748 - accuracy: 0.9259 - val_loss: 0.2855 - val_accuracy: 0.8741
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9358
# Epoch 10: val_accuracy improved from 0.88889 to 0.91852, saving model to /saved_models/model_1.h5
# 13/13 [==============================] - 29s 2s/step - loss: 0.1585 - accuracy: 0.9358 - val_loss: 0.1982 - val_accuracy: 0.9185
# 5/5 [==============================] - 8s 2s/step - loss: 0.1982 - accuracy: 0.9185
# 5/5 [==============================] - 7s 1s/step
#
#
# Cross Validation:  1
# accuracy:  0.9185185432434082
# precision:  0.9216064037161461
# recall:  0.9185185185185185
# f1 score:  0.9173776357848876
#
#
# Found 405 validated image filenames belonging to 3 classes.
# Found 135 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.2146 - accuracy: 0.3185
# Epoch 1: val_accuracy improved from -inf to 0.37037, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 31s 2s/step - loss: 1.2146 - accuracy: 0.3185 - val_loss: 1.0928 - val_accuracy: 0.3704
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0970 - accuracy: 0.3951
# Epoch 2: val_accuracy improved from 0.37037 to 0.66667, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 1.0970 - accuracy: 0.3951 - val_loss: 1.0857 - val_accuracy: 0.6667
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0648 - accuracy: 0.4963
# Epoch 3: val_accuracy did not improve from 0.66667
# 13/13 [==============================] - 28s 2s/step - loss: 1.0648 - accuracy: 0.4963 - val_loss: 1.0030 - val_accuracy: 0.6148
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.9191 - accuracy: 0.6222
# Epoch 4: val_accuracy did not improve from 0.66667
# 13/13 [==============================] - 28s 2s/step - loss: 0.9191 - accuracy: 0.6222 - val_loss: 0.8896 - val_accuracy: 0.4444
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.6198
# Epoch 5: val_accuracy improved from 0.66667 to 0.71111, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.7648 - accuracy: 0.6198 - val_loss: 0.6721 - val_accuracy: 0.7111
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5091 - accuracy: 0.8099
# Epoch 6: val_accuracy improved from 0.71111 to 0.77037, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 30s 2s/step - loss: 0.5091 - accuracy: 0.8099 - val_loss: 0.5243 - val_accuracy: 0.7704
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4037 - accuracy: 0.8420
# Epoch 7: val_accuracy improved from 0.77037 to 0.77778, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.4037 - accuracy: 0.8420 - val_loss: 0.4658 - val_accuracy: 0.7778
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8889
# Epoch 8: val_accuracy improved from 0.77778 to 0.82222, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.2865 - accuracy: 0.8889 - val_loss: 0.3530 - val_accuracy: 0.8222
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9012
# Epoch 9: val_accuracy improved from 0.82222 to 0.83704, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.2947 - accuracy: 0.9012 - val_loss: 0.3454 - val_accuracy: 0.8370
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1844 - accuracy: 0.9235
# Epoch 10: val_accuracy improved from 0.83704 to 0.87407, saving model to /saved_models/model_2.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.1844 - accuracy: 0.9235 - val_loss: 0.2615 - val_accuracy: 0.8741
# 5/5 [==============================] - 7s 1s/step - loss: 0.2615 - accuracy: 0.8741
# 5/5 [==============================] - 6s 1s/step
#
#
# Cross Validation:  2
# accuracy:  0.8740741014480591
# precision:  0.8762437963988351
# recall:  0.8740740740740741
# f1 score:  0.8738850096475721
#
#
# Found 405 validated image filenames belonging to 3 classes.
# Found 135 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.2490 - accuracy: 0.4222
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 31s 2s/step - loss: 1.2490 - accuracy: 0.4222 - val_loss: 1.0971 - val_accuracy: 0.3333
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0896 - accuracy: 0.3852
# Epoch 2: val_accuracy did not improve from 0.33333
# 13/13 [==============================] - 29s 2s/step - loss: 1.0896 - accuracy: 0.3852 - val_loss: 1.0844 - val_accuracy: 0.2667
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0326 - accuracy: 0.4864
# Epoch 3: val_accuracy improved from 0.33333 to 0.59259, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 28s 2s/step - loss: 1.0326 - accuracy: 0.4864 - val_loss: 0.9512 - val_accuracy: 0.5926
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6296
# Epoch 4: val_accuracy did not improve from 0.59259
# 13/13 [==============================] - 27s 2s/step - loss: 0.8635 - accuracy: 0.6296 - val_loss: 0.9032 - val_accuracy: 0.5185
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7300 - accuracy: 0.6765
# Epoch 5: val_accuracy improved from 0.59259 to 0.80741, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.7300 - accuracy: 0.6765 - val_loss: 0.5834 - val_accuracy: 0.8074
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4796 - accuracy: 0.8272
# Epoch 6: val_accuracy improved from 0.80741 to 0.83704, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.4796 - accuracy: 0.8272 - val_loss: 0.4001 - val_accuracy: 0.8370
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8272
# Epoch 7: val_accuracy did not improve from 0.83704
# 13/13 [==============================] - 27s 2s/step - loss: 0.4020 - accuracy: 0.8272 - val_loss: 0.4978 - val_accuracy: 0.8148
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.9062
# Epoch 8: val_accuracy improved from 0.83704 to 0.86667, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.2683 - accuracy: 0.9062 - val_loss: 0.3225 - val_accuracy: 0.8667
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8642
# Epoch 9: val_accuracy improved from 0.86667 to 0.90370, saving model to /saved_models/model_3.h5
# 13/13 [==============================] - 30s 2s/step - loss: 0.3281 - accuracy: 0.8642 - val_loss: 0.2442 - val_accuracy: 0.9037
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.8963
# Epoch 10: val_accuracy did not improve from 0.90370
# 13/13 [==============================] - 32s 3s/step - loss: 0.2713 - accuracy: 0.8963 - val_loss: 0.3018 - val_accuracy: 0.8963
# 5/5 [==============================] - 7s 1s/step - loss: 0.2442 - accuracy: 0.9037
# 5/5 [==============================] - 8s 2s/step
#
#
# Cross Validation:  3
# accuracy:  0.9037036895751953
# precision:  0.9216460905349795
# recall:  0.9037037037037037
# f1 score:  0.9058764501969371
#
#
# Found 405 validated image filenames belonging to 3 classes.
# Found 135 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 1.1274 - accuracy: 0.4025
# Epoch 1: val_accuracy improved from -inf to 0.51852, saving model to /saved_models/model_4.h5
# 13/13 [==============================] - 32s 2s/step - loss: 1.1274 - accuracy: 0.4025 - val_loss: 1.0877 - val_accuracy: 0.5185
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 1.0292 - accuracy: 0.5235
# Epoch 2: val_accuracy did not improve from 0.51852
# 13/13 [==============================] - 28s 2s/step - loss: 1.0292 - accuracy: 0.5235 - val_loss: 1.1008 - val_accuracy: 0.3630
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.9027 - accuracy: 0.6198
# Epoch 3: val_accuracy improved from 0.51852 to 0.63704, saving model to /saved_models/model_4.h5
# 13/13 [==============================] - 32s 3s/step - loss: 0.9027 - accuracy: 0.6198 - val_loss: 0.7531 - val_accuracy: 0.6370
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6067 - accuracy: 0.7556
# Epoch 4: val_accuracy improved from 0.63704 to 0.81481, saving model to /saved_models/model_4.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.6067 - accuracy: 0.7556 - val_loss: 0.5335 - val_accuracy: 0.8148
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8148
# Epoch 5: val_accuracy did not improve from 0.81481
# 13/13 [==============================] - 30s 2s/step - loss: 0.4537 - accuracy: 0.8148 - val_loss: 0.4679 - val_accuracy: 0.7778
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8222
# Epoch 6: val_accuracy did not improve from 0.81481
# 13/13 [==============================] - 29s 2s/step - loss: 0.4120 - accuracy: 0.8222 - val_loss: 0.6263 - val_accuracy: 0.6889
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8765
# Epoch 7: val_accuracy improved from 0.81481 to 0.83704, saving model to /saved_models/model_4.h5
# 13/13 [==============================] - 29s 2s/step - loss: 0.3290 - accuracy: 0.8765 - val_loss: 0.4123 - val_accuracy: 0.8370
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9086
# Epoch 8: val_accuracy did not improve from 0.83704
# 13/13 [==============================] - 28s 2s/step - loss: 0.2303 - accuracy: 0.9086 - val_loss: 0.4486 - val_accuracy: 0.8000
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9556
# Epoch 9: val_accuracy improved from 0.83704 to 0.84444, saving model to /saved_models/model_4.h5
# 13/13 [==============================] - 28s 2s/step - loss: 0.1581 - accuracy: 0.9556 - val_loss: 0.3761 - val_accuracy: 0.8444
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9506
# Epoch 10: val_accuracy did not improve from 0.84444
# 13/13 [==============================] - 32s 2s/step - loss: 0.1561 - accuracy: 0.9506 - val_loss: 0.5796 - val_accuracy: 0.7630
# 5/5 [==============================] - 6s 1s/step - loss: 0.3761 - accuracy: 0.8444
# 5/5 [==============================] - 7s 1s/step
#
#
# Cross Validation:  4
# accuracy:  0.8444444537162781
# precision:  0.8533607681755829
# recall:  0.8444444444444444
# f1 score:  0.8472025637074181

# %%
  model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 3,697,139
# Trainable params: 3,697,139
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # View the Performance Graphs

# %% [markdown]
# Acuracy, Precision, Recall, F1 Score **Ke 5 Fold**

# %%
fig, axs = plt.subplots(2,2,constrained_layout=True,figsize=(15,8))

axs[0,0].plot(CV, VALIDATION_ACCURACY, color='blue', marker='o', label="CNN")
axs[0,0].set_title('Accuracy')
axs[0,0].set_xlabel('Cross Validation')
axs[0,0].set_ylabel('Score')
axs[0,0].set_ylim((0.5, 1))
axs[0,0].grid()
axs[0,0].legend()

axs[0,1].plot(CV, VALIDATION_PRECISION, color='blue', marker='o', label="CNN")
axs[0,1].set_title('Precision')
axs[0,1].set_xlabel('Cross Validation')
axs[0,1].set_ylabel('Score')
axs[0,1].set_ylim((0.5, 1))
axs[0,1].grid()
axs[0,1].legend()

axs[1,0].plot(CV, VALIDATION_RECALL, color='blue', marker='o', label="CNN")
axs[1,0].set_title('Recall')
axs[1,0].set_xlabel('Cross Validation')
axs[1,0].set_ylabel('Score')
axs[1,0].set_ylim((0.5, 1))
axs[1,0].grid()
axs[1,0].legend()

axs[1,1].plot(CV, VALIDATION_F1SCORE, color='blue', marker='o', label="CNN")
axs[1,1].set_title('F1 Score')
axs[1,1].set_xlabel('Cross Validation')
axs[1,1].set_ylabel('Score')
axs[1,1].set_ylim((0.5, 1))
axs[1,1].grid()
axs[1,1].legend()

# %% [markdown]
# Accuracy dan Loss untuk **Ke 5 Fold**

# %%
n_epochs = 10
#set the x axis from 1
x_axis = np.arange(1, 11)

fig, ax = plt.subplots(4, 2, constrained_layout=True, figsize=(10,15))

for i in range(4):
  for j in range(2):
    if(j == 0):
      ax[i,j].set_title('CV' + str(i+1) + ' Loss')
      ax[i,j].set_ylabel('Loss')
      ax[i,j].plot(x_axis, LOSS[i], label='Training set')
      ax[i,j].plot(x_axis, VAL_LOSS[i], label='Test set', linestyle='--')
    else:
      ax[i,j].set_title('CV' + str(i+1) + ' Accuracy')
      ax[i,j].set_xlabel('Epoch')
      ax[i,j].set_ylabel('Accuracy')
      ax[i,j].plot(x_axis, ACCURACY[i], label='Training set')
      ax[i,j].plot(x_axis, VAL_ACCURACY[i], label='Test set', linestyle='--')
    ax[i,j].set_xlabel('Epoch')
    ax[i,j].set_ylim((0, 1))
    ax[i,j].set_xticks(np.arange(0, 11, 5))
    ax[i,j].legend()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 4.2 Testing on New Data

# %% [markdown]
# *   Percobaan 1 (Banjar Segar)

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/TugasAkhir/test_newdata/banjar_segar.jpg')
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# Untuk menampilkan hasil dalam bentuk desimal
np.set_printoptions(suppress=True) 

yhat = model.predict(np.expand_dims(resize/255, 0))
yhat

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/TugasAkhir/test_newdata/banjar_baik.jpg')
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# Untuk menampilkan hasil dalam bentuk desimal
np.set_printoptions(suppress=True) 

yhat = model.predict(np.expand_dims(resize/255, 0))
yhat

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/TugasAkhir/test_newdata/banjar_tidaklayak.jpg')
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# Untuk menampilkan hasil dalam bentuk desimal
np.set_printoptions(suppress=True) 

yhat = model.predict(np.expand_dims(resize/255, 0))
yhat

# %% [markdown]
# # Convert to TensorFlow Lite

# %% [markdown]
# 5.1 Save model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models', 'model-10epoch_4-foldcv.h5'))

# %% [markdown]
# 5.2 Convert to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %% [markdown]
# 5.3 Save .tflite model

# %%
with open("model-10epoch_4-foldcv.tflite", "wb") as f:
  f.write(tflite_model)

# %%
tflite_model_path = "model-10epoch_4-foldcv.tflite"

# %% [markdown]
# ---
#
#
#
# ---
